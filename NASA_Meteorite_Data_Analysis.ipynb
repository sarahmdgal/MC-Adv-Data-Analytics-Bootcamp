# %%
import json
import pandas as pd
import numpy as np

with open("nasa_meteorite_data.json", 'r', encoding='utf-8') as read_file:
    nasameteor = json.load(read_file)

# %%
nasameteor
# Out:
# [{'fall': 'Fell',
#   'geolocation': {'coordinates': [6.08333, 50.775], 'type': 'Point'},
#   'id': '1',
#   'mass': '21',
#   'name': 'Aachen',
#   'nametype': 'Valid',
#   'recclass': 'L5',
#   'reclat': '50.775000',
#   'reclong': '6.083330',
#   'year': '1880-01-01T00:00:00.000'},
#  {'fall': 'Fell',
#   'geolocation': {'coordinates': [10.23333, 56.18333], 'type': 'Point'},
#   'id': '2',
#   'mass': '720',
#   'name': 'Aarhus',
#   'nametype': 'Valid',
#   'recclass': 'H6',
#   'reclat': '56.183330',
#   'reclong': '10.233330',
#   'year': '1951-01-01T00:00:00.000'},
#  {'fall': 'Fell',
#   'geolocation': {'coordinates': [-113, 54.21667], 'type': 'Point'},
#   'id': '6',
#   'mass': '107000',
#   'name': 'Abee',
#   'nametype': 'Valid',
#   'recclass': 'EH4',
#   'reclat': '54.216670',
#   'reclong': '-113.000000',
#   'year': '1952-01-01T00:00:00.000'},
#  {'fall': 'Fell',
#   'geolocation': {'coordinates': [-99.9, 16.88333], 'type': 'Point'},
#   'id': '10',
# ...

# %%
nasameteoritedata1 = list(nasameteor)

# %%
type(nasameteoritedata)
# Out:
# list

# %%
df = pd.DataFrame(nasameteoritedata)
df.head(10)
# Out:
#   :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4  fall  \
# 0                         NaN                         NaN  Fell
# 1                         NaN                         NaN  Fell
# 2                         NaN                         NaN  Fell
# 3                         NaN                         NaN  Fell
# 4                         NaN                         NaN  Fell
# 5                         NaN                         NaN  Fell
# 6                         NaN                         NaN  Fell
# 7                         NaN                         NaN  Fell
# 8                         NaN                         NaN  Fell
# 9                         NaN                         NaN  Fell
#
#                                          geolocation   id    mass  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....    1      21
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...    2     720
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
nasameteoritedata2 = df.replace(np.nan, '', regex=True)

# %%
nasameteoritedata2
# Out:
#     :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4  fall  \
# 0                                                            Fell
# 1                                                            Fell
# 2                                                            Fell
# 3                                                            Fell
# 4                                                            Fell
# 5                                                            Fell
# 6                                                            Fell
# 7                                                            Fell
# 8                                                            Fell
# 9                                                            Fell
# 10                                                           Fell
# 11                                                           Fell
# 12                                                           Fell
# ...

# %%
print(nasameteoritedata2.columns)
# Out:
# Index([':@computed_region_cbhk_fwbd', ':@computed_region_nnqa_25f4', 'fall',
#        'geolocation', 'id', 'mass', 'name', 'nametype', 'recclass', 'reclat',
#        'reclong', 'year'],
#       dtype='object')

# %%
nasameteoritedata2.dtypes
# Out:
# :@computed_region_cbhk_fwbd    object
# :@computed_region_nnqa_25f4    object
# fall                           object
# geolocation                    object
# id                             object
# mass                           object
# name                           object
# nametype                       object
# recclass                       object
# reclat                         object
# reclong                        object
# year                           object
# dtype: object

# %%
CompiledNASAMeteoriteData = nasameteoritedata2.drop([':@computed_region_cbhk_fwbd', ':@computed_region_nnqa_25f4','geolocation' ], axis=1)

# %%
CompiledNASAMeteoriteData = nasameteoritedata2[['id', 'year', 'fall', 'name', 'nametype', 'reclat', 'reclong', 'recclass']]

# %%
CompiledNASAMeteoriteData.rename(columns = {'id':'ID'}, inplace = True)
CompiledNASAMeteoriteData.rename(columns = {'year':'Year'}, inplace = True)
CompiledNASAMeteoriteData.rename(columns = {'fall':'Fall'}, inplace = True)
CompiledNASAMeteoriteData.rename(columns = {'name':'Name'}, inplace = True)
CompiledNASAMeteoriteData.rename(columns = {'nametype':'NameType'}, inplace = True)
CompiledNASAMeteoriteData.rename(columns = {'mass':'Mass'}, inplace = True)
CompiledNASAMeteoriteData.rename(columns = {'reclat':'Latitude'}, inplace = True)
CompiledNASAMeteoriteData.rename(columns = {'reclong':'Longitude'}, inplace = True)
CompiledNASAMeteoriteData.rename(columns = {'recclass':'Type'}, inplace = True)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
CompiledNASAMeteoriteData.head(1000)
# Out:
#         ID                     Year  Fall                 Name NameType  \
# 0        1  1880-01-01T00:00:00.000  Fell               Aachen    Valid
# 1        2  1951-01-01T00:00:00.000  Fell               Aarhus    Valid
# 2        6  1952-01-01T00:00:00.000  Fell                 Abee    Valid
# 3       10  1976-01-01T00:00:00.000  Fell             Acapulco    Valid
# 4      370  1902-01-01T00:00:00.000  Fell              Achiras    Valid
# 5      379  1919-01-01T00:00:00.000  Fell             Adhi Kot    Valid
# 6      390  1949-01-01T00:00:00.000  Fell  Adzhi-Bogdo (stone)    Valid
# 7      392  1814-01-01T00:00:00.000  Fell                 Agen    Valid
# 8      398  1930-01-01T00:00:00.000  Fell               Aguada    Valid
# 9      417  1920-01-01T00:00:00.000  Fell        Aguila Blanca    Valid
# 10     423  1974-01-01T00:00:00.000  Fell     Aioun el Atrouss    Valid
# 11     424  1925-01-01T00:00:00.000  Fell                  Aïr    Valid
# ...
