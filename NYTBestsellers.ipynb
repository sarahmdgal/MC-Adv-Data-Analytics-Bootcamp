# %%
import requests
import json
import time
import pandas as pd

# %%
with open('NYT_BOOKS_API_KEY.TXT', 'r') as file:
    for line in file:
        api_key = line

# %%
url = r"https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key="

# %%
response = requests.get(url+api_key)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"status":"OK","copyright":"Copyright (c) 2019 The New York Times Company.  All Rights Reserved.","num_results":15,"last_modified":"2019-02-20T23:38:01-05:00","results":{"list_name":"Hardcover Fiction","list_name_encoded":"hardcover-fiction","bestsellers_date":"2019-02-16","published_date":"2019-03-03","published_date_description":"latest","next_published_date":"","previous_published_date":"2019-02-24","display_name":"Hardcover Fiction","normal_list_ends_at":15,"updated":"WEEKLY","books":[{"rank":1,"rank_last_week":2,"weeks_on_list":24,"asterisk":0,"dagger":0,"primary_isbn10":"0735219095","primary_isbn13":"9780735219090","publisher":"Putnam","description":"A woman who survived alone in the marsh becomes a murder suspect.","price":0,"title":"WHERE THE CRAWDADS SING","author":"Delia Owens","contributor":"by Delia Owens","contributor_note":"","book_image":"https:\\/\\/s1.nyt.com\\/du\\/books\\/images\\/9780735219090.jpg","book_image_width":328,"book_image_height":495,"amazon_product_ur
# ...

# %%
str_bestseller = response.text

# %%
bestseller_data = json.loads(str_bestseller)

# %%
bestseller_data
# Out:
# {'copyright': 'Copyright (c) 2019 The New York Times Company.  All Rights Reserved.',
#  'last_modified': '2019-02-20T23:38:01-05:00',
#  'num_results': 15,
#  'results': {'bestsellers_date': '2019-02-16',
#   'books': [{'age_group': '',
#     'amazon_product_url': 'https://www.amazon.com/Where-Crawdads-Sing-Delia-Owens/dp/0735219095?tag=NYTBS-20',
#     'article_chapter_link': '',
#     'asterisk': 0,
#     'author': 'Delia Owens',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780735219090.jpg',
#     'book_image_height': 495,
#     'book_image_width': 328,
#     'book_review_link': '',
#     'buy_links': [{'name': 'Local Booksellers',
#       'url': 'http://www.indiebound.org/book/9780735219090?aff=NYT'},
#      {'name': 'Barnes and Noble',
#       'url': 'http://www.anrdoezrs.net/click-7990613-11819508?url=http%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780735219090'},
#      {'name': 'Amazon',
# ...

# %%
lstBestseller_data = list(bestseller_data)

# %%
type(lstBestseller_data)
# Out:
# list

# %%
lstBestseller_data
# Out:
# ['status', 'copyright', 'num_results', 'last_modified', 'results']

# %%
bestseller_data.keys()
# Out:
# dict_keys(['status', 'copyright', 'num_results', 'last_modified', 'results'])

# %%
type(bestseller_data)
# Out:
# dict

# %%
lstNYBestsellers = bestseller_data['results']

# %%
lstNYBestsellers
# Out:
# {'bestsellers_date': '2019-02-16',
#  'books': [{'age_group': '',
#    'amazon_product_url': 'https://www.amazon.com/Where-Crawdads-Sing-Delia-Owens/dp/0735219095?tag=NYTBS-20',
#    'article_chapter_link': '',
#    'asterisk': 0,
#    'author': 'Delia Owens',
#    'book_image': 'https://s1.nyt.com/du/books/images/9780735219090.jpg',
#    'book_image_height': 495,
#    'book_image_width': 328,
#    'book_review_link': '',
#    'buy_links': [{'name': 'Local Booksellers',
#      'url': 'http://www.indiebound.org/book/9780735219090?aff=NYT'},
#     {'name': 'Barnes and Noble',
#      'url': 'http://www.anrdoezrs.net/click-7990613-11819508?url=http%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780735219090'},
#     {'name': 'Amazon',
#      'url': 'https://www.amazon.com/Where-Crawdads-Sing-Delia-Owens/dp/0735219095?tag=NYTBS-20'}],
#    'contributor': 'by Delia Owens',
#    'contributor_note': '',
#    'dagger': 0,
# ...

# %%
lstNYBestsellers.keys()
# Out:
# dict_keys(['list_name', 'list_name_encoded', 'bestsellers_date', 'published_date', 'published_date_description', 'next_published_date', 'previous_published_date', 'display_name', 'normal_list_ends_at', 'updated', 'books', 'corrections'])

# %%
df = pd.DataFrame(lstNYBestsellers['books'])
df.head(10)
# Out:
#   age_group                                 amazon_product_url  \
# 0            https://www.amazon.com/Where-Crawdads-Sing-Del...
# 1            https://www.amazon.com/Black-Leopard-Wolf-Dark...
# 2            https://www.amazon.com/Connections-Death-Dalla...
# 3            https://www.amazon.com/Girl-Greer-Hendricks/dp...
# 4            https://www.amazon.com/Silent-Patient-Alex-Mic...
# 5            https://www.amazon.com/Reckoning-Novel-John-Gr...
# 6            https://www.amazon.com/Devotions-Selected-Poem...
# 7            https://www.amazon.com/Fire-Blood-Thrones-Targ...
# 8            https://www.amazon.com/Love-Poems-Married-Peop...
# 9            https://www.amazon.com/Early-Riser-Novel-Jaspe...
#
#   article_chapter_link  asterisk                              author  \
# 0                              0                         Delia Owens
# 1                              0                        Marlon James
# ...
